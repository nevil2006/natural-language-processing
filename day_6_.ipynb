# %% [markdown]
# <a href="https://colab.research.google.com/github/nevil2006/natural-language-processing/blob/main/day_6_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow

# %%
import numpy as np
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, Dense

# %%
(X_train, y_train), (X_test, y_test) = imdb.load_data(num_words=5000)
# Out:
# ...
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
X_train = pad_sequences(X_train, maxlen=500)
X_test = pad_sequences(X_test, maxlen=500)

# %%
model = Sequential()

model.add(Embedding(input_dim=5000, output_dim=32))

model.add(SimpleRNN(32))

model.add(Dense(1, activation='sigmoid'))

# %%
Embedding(input_dim=5000, output_dim=32)
# Out:
# <Embedding name=embedding_2, built=False>

# %%
SimpleRNN(32)
# Out:
# <SimpleRNN name=simple_rnn_2, built=False>

# %%
Dense(1, activation='sigmoid')
# Out:
# <Dense name=dense_2, built=False>

# %%
model.compile(
    loss='binary_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# %%
model.fit(
    X_train,
    y_train,
    epochs=5,
    batch_size=64,
    validation_split=0.2
)
# Out:
# Epoch 1/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 41s 124ms/step - accuracy: 0.6223 - loss: 0.6325 - val_accuracy: 0.6842 - val_loss: 0.5841
# Epoch 2/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 41s 124ms/step - accuracy: 0.8015 - loss: 0.4431 - val_accuracy: 0.7838 - val_loss: 0.4712
# Epoch 3/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 38s 121ms/step - accuracy: 0.8587 - loss: 0.3340 - val_accuracy: 0.8192 - val_loss: 0.4096
# Epoch 4/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 41s 120ms/step - accuracy: 0.9148 - loss: 0.2203 - val_accuracy: 0.8156 - val_loss: 0.4619
# Epoch 5/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 39s 124ms/step - accuracy: 0.9534 - loss: 0.1342 - val_accuracy: 0.7958 - val_loss: 0.5364

# %%
loss, accuracy = model.evaluate(X_test, y_test)

print("Accuracy:", accuracy)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 19s 24ms/step - accuracy: 0.7990 - loss: 0.5345
# Accuracy: 0.7990000247955322
